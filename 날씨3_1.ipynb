# %% [markdown]
# ##### ~06/12
# 사실 이 전까지는 데이터 전처리도 그렇고 모델링에 대한 정확한 정의를 머릿속에 가지고 있지 않았던 것 같음
# etr, rf, xgb, lgmbr, gbr 다 써봄. etr을 best 모델로 써서 처음으로 csv 형식으로 결과값 출력해봄
# csi 0.014 acc 0.663 pag 0.025
# 근데 데이터 전처리할 때 컬럼 매핑하고 리네이밍해놔서 rainfall_train.@@@로 출력됨. 이거 출력할 때 다시 어떻게 돌리더라
#
# ##### 06/13
# 10월까지 포함해서 csi 0.012, 0.017(rf랑 etr 한 번씩 돌렸던 것 같은데 기억이 안 남.)
# accuracy가 안 나와서 아쉬움... 근데 아마 csi가 1 넘어야 80퍼 정도의 정확도가 나올 듯
# 근데 70퍼센트 대까지만 나와도 좋을 듯
#
# ##### 06/14
# model.fit이랑 randomized.fit을 같이 써야 하는지 모르겠어서 model.fit을 지웠다가 그냥 다시 살려둠.
#
# ##### 06/15
# 시간낭비 오지게 함. 삽질 그 자체임
#
# ##### 06/17
# xgboost, lgmbr, gbr 도 써봤지만 10만 건의 데이터 샘플로 돌렸을 때 성능이 현저히 떨어지는 결과를 얻어서 배제.
# 0.014, 0.012, 0.017 나오다가 0.003 나옴 ㅋㅋ
# random forest와 extra tree 두 모델 중 과적합 없이 더 나은 성능을 보이는 모델로 선정하여 하이퍼 파라미터 튜닝할 예정
# 근데 왜 계속 데이터셋이 안 맞다고 하는지 이해가 안됨.
# ipynb 파일로 flask 파일 만들기 전에 train 데이터로
# stn 0nn, ef year, ef month, ef day 선택하면 hour 마다의 누적 강수량(vv) 나오는 거 만들었음.
# 그런데 flask로 만들다가 exception 나서 다음날 다시 하기로 함.
#
# ##### 06/17
# 여전히 데이터셋 안 맞다고 나옴. 왤까?
#
# ipynb 파일-> app.py 파일로 만들고
#
# 폴더도
# my_flask_project/
#     ├── flask_app/
#     │   ├── app.py
#     │   ├── rainfall_train.csv
#     │   └── requirements.txt
# 구조로 만들어서 토스함.
#
# randomizedSearchCV를 샘플 데이터 10만 건으로 하니까 best estimators의 최대 스코어가 0.67의 정확도까지만 나오나봄.
#
# etr 최종 모델 train score : 0.6766616350976211
# etr 최종 모델 test mse : 1875.4968441119938
# etr 최종 모델 test score r2 : 0.6733642170906967
#
# 그래서 20만 건으로 샘플 데이터를 늘렸는데 그렇게 하니까 test score 더 낮아짐 왤까 최종 모델이 아니라서 그런가
#
# etr 검증 mse : 5259.364112525381
# etr test score r2: 0.08403124223159819
#
# 문제는 시간이 너무 오래 걸림 gridSearchCV 벗어났다고 좋아했더니 역시 20만 건이라 randomized로 돌리더라도 좀 걸리나봄.
#
# 그래도 역시 최종모델의 정확도는 올라감.
#
# rf 최적 파라미터: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 30}
# rf 검증 mse : 5114.00743547955
# rf test score r2: 0.10934650317539363
# etr 최종 모델 train score : 0.7893433288700815
# etr 최종 모델 test mse : 1220.6538306297214
# etr 최종 모델 test score r2 : 0.78741141533738
# rf 최종 모델 train score : 0.721890902499683
# rf 최종 모델 test mse : 1625.8879680279636
# rf 최종 모델 test score r2 : 0.7168359994702729
#
# -> 근데 이거 결국 train data를 split해서 train이랑 test로 나눠서 저렇게 나오는 거임. test 따로 넣었을 때는 이 결과값 장담 못 함
#
# #### 06/18
# 위에 최종모델 정확도 올라간 놈 검증하니까 어제 0.003으로 확 떨어졌다가 다시 0.017로 올라옴
# csi 0.014 의 정확도가 0.663이었으니까 한 0.02쯤 되면 test score가 0.7대로 진입할까 싶음. 근데 문제는 accuracy랑 csi 상관관계가 정확히 어떻게 되는 거지? 내가 예상한 값이 맞는지 모르겠음.
#
# +)
# 이상현 교수님이 부르셔서 앞에 나갔는데 저번에 김경민 교수님한테 혼났던 거랑 똑같은 걸로 혼남.
# 교수님들이 말씀하신 제일 큰 문제
# 1. 피쳐값 뭔지 안 정하면 어떡하냐
# 2. 둘이 지금 협업 안 되고 있다
#
# #### 6/19
#
#
# #### 6/20
# 피쳐값 19개 보내면 결과값이랑 구간 나오는 거
#
# 6/21 금
# → 휴가 씀
# 6/22 토
# 6/23 일
#
# ##### 6/24
# 이상치 제거했더니 정확도 떨어짐. 그냥 야생으로 가야 할 듯
# etr 최종 모델 train score : 0.7030322496006853
# etr 최종 모델 test mse : 4695.3013555837015
# etr 최종 모델 test score r2 : 0.2084984597243409
# rf 최종 모델 train score : 0.6967751916256586
# rf 최종 모델 test mse : 4140.307391962789
# rf 최종 모델 test score r2 : 0.3020555168293658
# 앙상블 모델 Test MSE: 5919.271992177037
# 앙상블 모델 Test Score r2: 0.0021699259948227967
# 참가번호 240484 의 정확도는 CSI: 0.013 입니다.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint

# %%
import pandas as pd
# train 데이터 불러오기
train_data = pd.read_csv('./rainfall_train.csv')
# test 데이터 불러오기
test_data = pd.read_csv('./Test_rainfall_test_test.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
# train 데이터타입 화깅ㄴ
print(train_data.dtypes)
# Out:
# Unnamed: 0                         int64
# rainfall_train.fc_year            object
# rainfall_train.fc_month            int64
# rainfall_train.fc_day              int64
# rainfall_train.fc_hour             int64
# rainfall_train.stn4contest        object
# rainfall_train.dh                  int64
# rainfall_train.ef_year            object
# rainfall_train.ef_month            int64
# rainfall_train.ef_day              int64
# rainfall_train.ef_hour             int64
# rainfall_train.v01                 int64
# rainfall_train.v02                 int64
# rainfall_train.v03                 int64
# rainfall_train.v04                 int64
# rainfall_train.v05                 int64
# rainfall_train.v06                 int64
# rainfall_train.v07                 int64
# rainfall_train.v08                 int64
# rainfall_train.v09                 int64
# rainfall_train.vv                float64
# rainfall_train.class_interval      int64
# dtype: object

# %%
# test 데이터 타입
print(test_data.dtypes)
# Out:
# rainfall_test.fc_year            object
# rainfall_test.fc_month            int64
# rainfall_test.fc_day              int64
# rainfall_test.fc_hour             int64
# rainfall_test.stn4contest        object
# rainfall_test.dh                  int64
# rainfall_test.ef_year            object
# rainfall_test.ef_month            int64
# rainfall_test.ef_day              int64
# rainfall_test.ef_hour             int64
# rainfall_test.v01                 int64
# rainfall_test.v02                 int64
# rainfall_test.v03                 int64
# rainfall_test.v04                 int64
# rainfall_test.v05                 int64
# rainfall_test.v06                 int64
# rainfall_test.v07                 int64
# rainfall_test.v08                 int64
# rainfall_test.v09                 int64
# rainfall_test.class_interval    float64
# dtype: object

# %%
# train 데이터 결측치
train_data.isnull().sum()
# Out:
# Unnamed: 0                       0
# rainfall_train.fc_year           0
# rainfall_train.fc_month          0
# rainfall_train.fc_day            0
# rainfall_train.fc_hour           0
# rainfall_train.stn4contest       0
# rainfall_train.dh                0
# rainfall_train.ef_year           0
# rainfall_train.ef_month          0
# rainfall_train.ef_day            0
# rainfall_train.ef_hour           0
# rainfall_train.v01               0
# rainfall_train.v02               0
# rainfall_train.v03               0
# rainfall_train.v04               0
# rainfall_train.v05               0
# rainfall_train.v06               0
# rainfall_train.v07               0
# rainfall_train.v08               0
# rainfall_train.v09               0
# rainfall_train.vv                0
# rainfall_train.class_interval    0
# dtype: int64

# %%
# test 데이터 결측치 보기
test_data.isnull().sum()
# Out:
# rainfall_test.fc_year                0
# rainfall_test.fc_month               0
# rainfall_test.fc_day                 0
# rainfall_test.fc_hour                0
# rainfall_test.stn4contest            0
# rainfall_test.dh                     0
# rainfall_test.ef_year                0
# rainfall_test.ef_month               0
# rainfall_test.ef_day                 0
# rainfall_test.ef_hour                0
# rainfall_test.v01                    0
# rainfall_test.v02                    0
# rainfall_test.v03                    0
# rainfall_test.v04                    0
# rainfall_test.v05                    0
# rainfall_test.v06                    0
# rainfall_test.v07                    0
# rainfall_test.v08                    0
# rainfall_test.v09                    0
# rainfall_test.class_interval    121870
# dtype: int64

# %%
# # 카테고리형 변환
# train_data['rainfall_train.fc_year'] = train_data['rainfall_train.fc_year'].astype('category').cat.codes
# train_data['rainfall_train.ef_year'] = train_data['rainfall_train.ef_year'].astype('category').cat.codes
# train_data['rainfall_train.stn4contest'] = train_data['rainfall_train.stn4contest'].astype('category').cat.codes

# test_data['rainfall_test.fc_year'] = test_data['rainfall_test.fc_year'].astype('category').cat.codes
# test_data['rainfall_test.ef_year'] = test_data['rainfall_test.ef_year'].astype('category').cat.codes
# test_data['rainfall_test.stn4contest'] = test_data['rainfall_test.stn4contest'].astype('category').cat.codes

# %%
column_mapping = {
    'rainfall_test.fc_year': 'rainfall_train.fc_year',
    'rainfall_test.fc_month': 'rainfall_train.fc_month',
    'rainfall_test.fc_day': 'rainfall_train.fc_day',
    'rainfall_test.fc_hour': 'rainfall_train.fc_hour',
    'rainfall_test.ef_year': 'rainfall_train.ef_year',
    'rainfall_test.ef_month': 'rainfall_train.ef_month',
    'rainfall_test.ef_day': 'rainfall_train.ef_day',
    'rainfall_test.ef_hour': 'rainfall_train.ef_hour',
    'rainfall_test.dh': 'rainfall_train.dh',
    'rainfall_test.stn4contest': 'rainfall_train.stn4contest',
    'rainfall_test.v01': 'rainfall_train.v01',
    'rainfall_test.v02': 'rainfall_train.v02',
    'rainfall_test.v03': 'rainfall_train.v03',
    'rainfall_test.v04': 'rainfall_train.v04',
    'rainfall_test.v05': 'rainfall_train.v05',
    'rainfall_test.v06': 'rainfall_train.v06',
    'rainfall_test.v07': 'rainfall_train.v07',
    'rainfall_test.v08': 'rainfall_train.v08',
    'rainfall_test.v09': 'rainfall_train.v09'
}

test_data = test_data.rename(columns=column_mapping)


# 변경된 컬럼 이름 확인
print(test_data.columns)
# Out:
# Index(['rainfall_train.fc_year', 'rainfall_train.fc_month',
#        'rainfall_train.fc_day', 'rainfall_train.fc_hour',
#        'rainfall_train.stn4contest', 'rainfall_train.dh',
#        'rainfall_train.ef_year', 'rainfall_train.ef_month',
#        'rainfall_train.ef_day', 'rainfall_train.ef_hour', 'rainfall_train.v01',
#        'rainfall_train.v02', 'rainfall_train.v03', 'rainfall_train.v04',
#        'rainfall_train.v05', 'rainfall_train.v06', 'rainfall_train.v07',
#        'rainfall_train.v08', 'rainfall_train.v09',
#        'rainfall_test.class_interval'],
#       dtype='object')

# %%
# train 데이터 컬럼명 단순화
fc_year = 'rainfall_train.fc_year'
fc_month = 'rainfall_train.fc_month'
fc_day = 'rainfall_train.fc_day'
fc_hour = 'rainfall_train.fc_hour'
stn4contest = 'rainfall_train.stn4contest'
dh = 'rainfall_train.dh'
ef_year = 'rainfall_train.ef_year'
ef_month = 'rainfall_train.ef_month'
ef_day = 'rainfall_train.ef_day'
ef_hour = 'rainfall_train.ef_hour'
v01 = 'rainfall_train.v01'
v02 = 'rainfall_train.v02'
v03 = 'rainfall_train.v03'
v04 = 'rainfall_train.v04'
v05 = 'rainfall_train.v05'
v06 = 'rainfall_train.v06'
v07 = 'rainfall_train.v07'
v08 = 'rainfall_train.v08'
v09 = 'rainfall_train.v09'
vv = 'rainfall_train.vv'
class_interval = 'rainfall_train.class_interval'

# %%
features = [v01, v02, v03, v04, v05, v06, v07, v08, v09]

# %%
X_train = train_data[features]
y_train = train_data[vv]

# %%
X_train_split, X_test, y_train_split, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# param_grid = {
#     'n_estimators': [100, 200],           # 트리 개수
#     'max_depth': [5, 10, 20],             # 트리 최대 깊이
#     'min_samples_split': [2, 5, 10],      # 내부 노드 분할에 필요한 최소 샘플 수
#     'min_samples_leaf': [1, 2, 4],        # 리프 노드에 필요한 최소 샘플 수
#     'max_features': ['auto', 'sqrt', 'log2']  # 각 분할에서 고려할 최대 피처 수
# }

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor

# 모델
rf = RandomForestRegressor(n_estimators=100, random_state=42)
etr = ExtraTreesRegressor(n_estimators=100, random_state=42)

models = {
    "rf" : rf,
    "etr" : etr 
}

# %%
# 학습
rf.fit(X_train, y_train)
etr.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=42)

# %%
# 예측값
rf_pred = rf.predict(X_test)
etr_pred = etr.predict(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

sample_size = min(200000, len(X_train_split))
X_train_sample = X_train_split.sample(n=sample_size, random_state=42)
y_train_sample = y_train_split.loc[X_train_sample.index]

param_distributions = {
    'n_estimators': randint(10, 200),
    'max_features': randint(1, X_train_sample.shape[1]),
    'max_depth': randint(1, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20)
    }

# %%
from sklearn.metrics import mean_squared_error, r2_score
best_estimators = {}

for name, model in models.items():
    random_search = RandomizedSearchCV(model, param_distributions, n_iter=50, cv=3, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
    random_search.fit(X_train, y_train)  # fit 메서드를 호출합니다.
    train_score = model.score(X_train, y_train)
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    test_score = r2_score(y_test, predictions)
    best_estimators[name] = random_search.best_estimator_
    print(f"{name} 최적 파라미터: {random_search.best_params_}")
    print(f'{name} Train Score: {train_score}')
    print(f'{name} 검증 MSE: {mse}')
    print(f'{name} Test Score: {test_score}')
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# rf 최적 파라미터: {'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 11, 'min_samples_split': 14, 'n_estimators': 84}
# rf Train Score: 0.3492995736674692
# rf 검증 MSE: 3703.5939687527025
# rf Test Score: 0.3549835504338098
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 6
#       4 for name, model in models.items():
#       5     random_search = RandomizedSearchCV(model, param_distributions, n_iter=50, cv=3, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
# ----> 6     random_search.fit(X_train, y_train)  # fit 메서드를 호출합니다.
#       7     train_score = model.score(X_train, y_train)
#       8     predictions = model.predict(X_test)
#
# ...

# %%
# 예측값
rf_pred = rf.predict(X_test)
etr_pred = etr.predict(X_test)

# %%
# # 학습 및 평가
# for name, model in models.items():
#     model.fit(X_train, y_train)
#     train_score = model.score(X_train, y_train)
#     predictions = model.predict(X_test)
#     mse = mean_squared_error(y_test, predictions)
#     test_score = r2_score(y_test, predictions)
#     print(f'{name} Train Score: {train_score}')
#     print(f'{name} Test MSE: {mse}')
#     print(f'{name} Test Score: {test_score}')
# Out:
# rf Train Score: 0.3492995736674692
# rf Test MSE: 3703.5939687527025
# rf Test Score: 0.3549835504338098
# etr Train Score: 0.39042925575893783
# etr Test MSE: 3453.454842199594
# etr Test Score: 0.3985476810237544

# %%
# best_estimators = {}
# for model_name, model in models.items():
#     random_search = RandomizedSearchCV(model, param_distributions, n_iter=50, cv=3, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
#     random_search.fit(X_train_sample, y_train_sample)
#     best_estimators[model_name] = random_search.best_estimator_
#     print(f"{model_name} 최적 파라미터: {random_search.best_params_}")
#     y_pred = random_search.predict(X_test)
#     mse = mean_squared_error(y_test, y_pred)
#     print(f"{model_name} 검증 MSE: {mse}")
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       2 for model_name, model in models.items():
#       3     random_search = RandomizedSearchCV(model, param_distributions, n_iter=50, cv=3, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
# ----> 4     random_search.fit(X_train_sample, y_train_sample)
#       5     best_estimators[model_name] = random_search.best_estimator_
#       6     print(f"{model_name} 최적 파라미터: {random_search.best_params_}")
#
# File c:\Users\uear\anaconda3\envs\py3_11\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
# ...

# %%
# 예측 값을 class_interval로 변환하는 함수 정의
def vv_to_class_interval(vv):
    if vv <= 0.1:
        return 0
    elif 0.1< vv <= 0.2:
        return 1
    elif 0.2 < vv <= 0.5:
        return 2
    elif 0.5 < vv <= 1.0:
        return 3
    elif 1.0 < vv <= 2.0:
        return 4
    elif 2.0 < vv <= 5.0:
        return 5
    elif 5.0 < vv <= 10.0:
        return 6
    elif 10.0 < vv <= 20.0:
        return 7
    elif 20.0 < vv <= 30.0:
        return 8
    else:
        return 9

# %%
# 최적 모델로 예측
for name, model in best_estimators.items():
    test_predictions = model.predict(X_test)
    test_predictions_series = pd.Series(test_predictions)
    test_data[f'{name}_class_interval'] = test_predictions_series.apply(vv_to_class_interval)

# %%
# 결과 저장
test_data.to_csv('./rainfall_test_0617-1.csv', index=False)

# %%
print(X_test.info())

# %%
print(model.predict(X_test))

# %%
# best_estimators = {}
# for model_name, model in models.items():
#     grid_search = TQDMSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
#     grid_search.fit(X_train_split, y_train_split)
#     best_estimators[model_name] = grid_search.best_estimator_
#     print(f"{model_name} best params: {grid_search.best_params_}")
#     y_pred = grid_search.predict(X_test)
#     mse = mean_squared_error(y_test, y_pred)
#     print(f"{model_name} validation MSE: {mse}")
# 아 시간 너무 오래 걸리네... 어떻게 24시간 넘게 돌려도 끝나질 않냐 randomized로 넘어가야되네...

# %%
# etr 로 예측
best_model = best_estimators['etr']
test_predictions = best_model.predict(X_test)

# %%
# etr 로 예측
best_model = best_estimators["rf"] 
test_predictions = best_model.predict(X_test)

# %%
import pandas as pd

# 예측 결과를 pandas 시리즈로 변환
test_predictions_series = pd.Series(test_predictions)

# %%
def vv_to_class_interval(vv):
    if vv < 0.1:
        return 0
    elif vv < 0.2:
        return 1
    elif vv < 0.5:
        return 2
    elif vv < 1.0:
        return 3
    elif vv < 2.0:
        return 4
    elif vv < 5.0:
        return 5
    elif vv < 10.0:
        return 6
    elif vv < 20.0:
        return 7
    elif vv < 30.0:
        return 8
    else:
        return 9

# %%
# 예측 결과에 함수 적용
test_data['rainfall_test.class_interval'] = test_predictions_series.apply(vv_to_class_interval)

# 결과 확인
print(test_data['rainfall_test.class_interval'])

# %%
test_data.to_csv('./rainfall_test0614_1.csv', index=False)
